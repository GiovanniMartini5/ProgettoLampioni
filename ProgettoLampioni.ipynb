# %% [markdown]
# <a href="https://colab.research.google.com/github/GiovanniMartini5/ProgettoLampioni/blob/main/ProgettoLampioni.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install ultralytics

# %%
from ultralytics import YOLO
from IPython.display import display, Image

model = YOLO('yolov8n.pt')

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key=)
project = rf.workspace("sapienza-mc7t5").project("progetto-lampioni")
version = project.version(21)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.1.24, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to Progetto-lampioni-21 in yolov8:: 100%|██████████| 10062/10062 [00:01<00:00, 6340.37it/s]

# %%
# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=100 imgsz=640
# Out:
# Ultralytics YOLOv8.1.24 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
Image(filename=f'runs/detect/train/confusion_matrix.png', width=1000)

# %%
Image(filename=f'runs/detect/train/results.png', width=1000)

# %%
project.version(21).deploy(model_type="yolov8", model_path=f"runs/detect/train/")
